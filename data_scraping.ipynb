# %% [markdown]
# ## Dataset 1: UCSD CAPE Reviews
# - Contains the student evaluations for each class at UCSD, including percentage of students who recommend the instructor and the class, the average number of weeks spent on the class, and the average grade expected and received for the class
# - To run the code below, you will need the following:
#     - You will need to first log in to your UCSD account so that the cookies on the cape.ucsd.edu website contains your log-in information that is necessary to access the CAPE reviews
#     - Once you've logged into your UCSD account, go to the cape.ucsd.edu page and download the cookies in a json format. One way to do this is to use the Chrome extension "Export cookie JSON file for Puppeteer" (https://chromewebstore.google.com/detail/export-cookie-json-file-f/nmckokihipjgplolmcmjakknndddifde?pli=1)
#
# Credit to u/MaxtheBat on Reddit for the code below. He posted the code on scraping UCSD CAPE data in the Reddit post below:
#
# https://www.reddit.com/r/UCSD/comments/14uh5q5/since_capes_is_being_retired_i_scraped_all_its/

# %%
import requests
import json
from bs4 import BeautifulSoup

# %%
# Load in cookies
cookies_raw = json.load(open('cookies/cape.ucsd.edu.cookies.json', 'r'))
cookies = {cookie['name']: cookie['value'] for cookie in cookies_raw}

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82 Safari/537.36',
    'Accept-Encoding': '*',
    'Connection': 'keep-alive'
}

# %%
url = 'https://cape.ucsd.edu/responses/Results.aspx?Name=%2C&CourseNumber='

# %%
# Initiate get request to CAPEs (with all entries)
response = requests.get(url, cookies=cookies, headers=headers)

# %%
# Parse request and scrape table
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('table')
table_body = table.find('tbody')
rows = table_body.find_all('tr')

# %%
# Parse each row for data and put in list
data = []
for row in rows:
    cols = row.find_all('td')
    url = 'https://cape.ucsd.edu/' + row.find('a')['href'].strip('../')
    cols = [ele.text.strip().replace(',', '') for ele in cols]
    cols.append(url)
    data.append([ele for ele in cols if ele])

# %%
# Open file
with open('data/capes_data.csv', 'w', encoding='utf-8') as file:
    # Write file header
    file.write('Instructor,Course,Quarter,Total Enrolled in Course,Total CAPEs Given,Percentage Recommended Class,Percentage Recommended Professor,Study Hours per Week,Average Grade Expected,Average Grade Received,Evalulation URL\n')
    
    # Write course data
    for course in data:
        file.write(','.join(course))
        file.write('\n')

# %% [markdown]
# ## Dataset 2: UCSD Course Catalog

# %%
catalog_url = 'https://catalog.ucsd.edu/front/courses.html'

# %%
# Fetch the content from the URL
response = requests.get(catalog_url)
content = response.content

# %%
# Parse the content with BeautifulSoup
soup = BeautifulSoup(content, 'html.parser')

# %%
# Find all links in the page
links = soup.find_all('a', href=True)

# %%
links
# Out:
# [<a class="sr-only skip-to-main" href="#main-content">Skip to main content</a>,
#  <a class="title-header title-header-large" href="/">
#              General Catalog
#      </a>,
#  <a class="title-header title-header-short" href="/">
#              General Catalog
#      </a>,
#  <a class="title-logo" href="http://www.ucsd.edu">UC San Diego</a>,
#  <a href="https://catalog.ucsd.edu/front/courses.html">Courses/Curricula/Faculty</a>,
#  <a href="../about/index.html">About <span class="caret"></span> </a>,
#  <a href="../archive/index.html">Archive</a>,
#  <a href="../index.html">HOME</a>,
#  <a href="https://catalog.ucsd.edu/front/courses.html">Courses/Curricula/Faculty</a>,
#  <a href="#A">A</a>,
#  <a href="#A">B</a>,
#  <a href="#C">C</a>,
#  <a href="#C">D</a>,
#  <a href="#E">E</a>,
#  <a href="#F">F</a>,
#  <a href="#F">G</a>,
#  <a href="#F">H</a>,
#  <a href="#I">I</a>,
#  <a href="#I">J</a>,
#  <a href="#I">K</a>,
#  <a href="#L">L</a>,
#  <a href="#M">M</a>,
#  <a href="#N">N</a>,
#  <a href="#N">O</a>,
#  <a href="#N">P</a>,
#  <a href="#R">R</a>,
#  <a href="#R">S</a>,
#  <a href="#T">T</a>,
#  <a href="#T">U</a>,
#  <a href="#T">V</a>,
#  <a href="#T">W</a>,
#  <a href="../curric/AIP.html" title="Academic Internship Program">undergraduate program</a>,
#  <a href="../courses/AIP.html" title="Academic Internship Program">courses</a>,
#  <a href="../pdf/AIP.pdf" title="Academic Internship Program">pdf</a>,
#  <a href="../curric/AASM.html" title="African American Studies Minor">undergraduate program</a>,
#  <a href="../courses/AASM.html" title="African American Studies Minor">courses</a>,
#  <a href="../faculty/AASM.html" title="AASM">faculty</a>,
#  <a href="../pdf/AUDL.pdf" title="Audiology">pdf</a>,
#  <a href="../curric/AFRI.html" title="African Studies Minor">undergraduate program</a>,
#  <a href="../faculty/AFRI.html" title="African Studies Minor Program">faculty</a>,
#  <a href="../pdf/AFRI.pdf" title="African American Studies Minor">pdf</a>,
#  <a href="../courses/AWP.html" title="Anthropology">courses</a>,
#  <a href="../curric/ANTH-ug.html" title="Anthropology">undergraduate program</a>,
#  <a href="../curric/ANTH-gr.html" title="Anthropology">graduate program</a>,
#  <a href="../courses/ANTH.html" title="Anthropology">courses</a>,
#  <a href="../faculty/ANTH.html" title="Anthropology">faculty</a>,
#  <a href="../pdf/ANTH.pdf" title="Anthropology">pdf</a>,
#  <a href="../curric/APOC.html" title="Applied Ocean Science">graduate program</a>,
#  <a href="../faculty/APOC.html" title="Applied Ocean Science">faculty</a>,
#  <a href="../pdf/APOC.pdf" title="Applied Ocean Science">pdf</a>,
#  <a href="../curric/AAPI.html" title="African American Studies Minor">undergraduate program</a>,
#  <a href="../courses/AAPI.html">courses</a>,
#  <a href="../faculty/AAPI.html" title="Asian American and Pacific Islander Studies Minor Program">faculty</a>,
#  <a href="../curric/ASTR.html" title="Astronomy and Astrophysics">undergraduate program</a>,
#  <a href="../curric/AUDL.html" title="Audiology">graduate program</a>,
#  <a href="../courses/AUDL.html" title="Audiology">courses</a>,
#  <a href="../faculty/AUDL.html" title="Audiology">faculty</a>,
#  <a href="../pdf/AUDL.pdf" title="Audiology">pdf</a>,
#  <a href="../curric/BIOC.html" title="Biochemistry">undergraduate program</a>,
#  <a href="../pdf/BIOC.pdf" title="Biochemistry">pdf</a>,
#  <a href="#beng">Bioengineering</a>,
#  <a href="#jsoe">Engineering, Jacobs School of</a>,
#  <a href="../curric/BIOI-ug.html" title="Bioinformatics">undergraduate program</a>,
#  <a href="../pdf/THEA.pdf" title="Theatre and Dance">pdf</a>,
#  <a href="../curric/TMC.html" title="Thurgood Marshall College">undergraduate program</a>,
#  <a href="../courses/TMC.html" title="Thurgood Marshall College">courses</a>,
#  <a href="../pdf/TMC.pdf" title="Thurgood Marshall College">pdf</a>,
#  <a href="../curric/KOR.html" title="Korean Studies">undergraduate program</a>,
#  <a href="../faculty/KOR.html">faculty</a>,
#  <a href="../curric/UCDC.html" title="UC San Diego Washington Center">undergraduate program</a>,
#  <a href="../pdf/UCDC.pdf" title="UC San Diego Washington Center">pdf</a>,
#  <a href="#fres">First-year Student</a>,
#  <a href="#seni">Senior</a>,
#  <a href="../curric/USP.html" title="Urban Studies and Planning">undergraduate program</a>,
#  <a href="../courses/USP.html" title="Urban Studies and Planning">courses</a>,
#  <a href="../faculty/USP.html" title="Urban Studies and Planning">faculty</a>,
#  <a href="../pdf/USP.pdf" title="Urban Studies and Planning">pdf</a>,
#  <a href="../curric/VIS-ug.html" title="Visual Arts">undergraduate program</a>,
#  <a href="../curric/VIS-gr.html" title="Visual Arts">graduate program</a>,
#  <a href="../courses/VIS.html" title="Visual Arts">courses</a>,
#  <a href="../faculty/VIS.html" title="Visual Arts">faculty</a>,
#  <a href="../pdf/VIS.pdf" title="Visual Arts">pdf</a>,
#  <a href="../curric/WARR.html" title="Warren College">undergraduate program</a>,
#  <a href="../courses/WARR.html" title="Warren College">courses</a>,
#  <a href="../pdf/WARR.pdf" title="Warren College">pdf</a>,
#  <a href="https://accessibility.ucsd.edu/report-a-concern/index.html">Accessibility</a>,
#  <a href="https://ucsd.edu/about/privacy-policy.html">Privacy Policy</a>,
#  <a href="https://ucsd.edu/about/terms-of-use.html">Terms of Use</a>,
#  <a href="https://act.ucsd.edu/cwp/feedback/tool/cwo">Feedback</a>,
#  <a href="https://ucsd.edu/"><img alt="UCSD homepage" class="img-responsive footer-logo" src="https://cdn.ucsd.edu/developer/decorator/5.0.2/img/ucsd-footer-logo-white.png"/></a>]

# %%
# Get all links for the department pages that contain course information
base_url = "../courses/"
department_links = [link['href'] for link in links if link['href'].startswith(base_url)]
department_links = ["https://catalog.ucsd.edu" + link.strip('..') for link in department_links]

# %%
import pandas as pd
import re

# %%
missing_units = {'COMM 101A': '4', 'HIEU 124': '4', \
                 'HILA 119': '4', 'JAPN 180': '4', \
                 'JAPN 190': '4', 'LIGN 9GS': '4', \
                 'USP 131': '4', 'USP 141A': '6', \
                 'USP 141B': '6'}

# %%
course_info = []

for dept in department_links:
    print(dept)
    # get content from department page
    response = requests.get(dept)
    content = response.content
    soup = BeautifulSoup(content, 'html.parser')

    # Get the course names and course descriptions
    course_name_elements = soup.find_all('p', class_='course-name')

    # Extract the course code, department, title, units, description and prerequisites
    for tag in course_name_elements:
        course_description_element = tag.find_next_siblings('p', limit=1)[0]

        content = response.content
    soup = BeautifulSoup(content, 'html.parser')

    # Get the course names and course descriptions
    course_name_elements = soup.find_all('p', class_='course-name')

    # Extract the course code, department, title, units, description and prerequisites
    for tag in course_name_elements:
        course_description_element = tag.find_next_siblings('p', limit=1)[0]

        full_course_name = tag.get_text().strip()
        full_course_description = course_description_element.get_text().strip()

        # Special Case: For Languages classes, the course code is formatted differently
        if full_course_name.startswith("Linguistics"):
            course_code = full_course_name.split('(')[1].split('.')[0].replace(')', '')
        else:
            if '.' in full_course_name:

                course_code = full_course_name.split('.')[0]
            else:

                course_code = ' '.join(full_course_name.split()[:2]).split('.')[0]

        course_dept = course_code.split()[0]

        # Special Case: Some courses don't have units listed
        if "(" in full_course_name:
            if "." in full_course_name:
                course_title = '('.join(full_course_name.split('(')[:-1]).split('.')[1].strip() # full_course_name.split('(')[-2].split('.')[1].strip()
            else:
                course_title = ' '.join(full_course_name.split(' ')[2:]).strip()
            course_units = re.findall(r'\((.*?)\)', full_course_name)[-1]
        else:
            course_title = ' '.join(full_course_name.split(' ')[2:]).strip()
            course_units = missing_units[course_code]

        course_description = full_course_description.split('Prerequisites:')[0].strip()

        if "Prerequisites" in full_course_description:
            course_prerequisites = full_course_description.split('Prerequisites:')[1].strip()
        else:
            course_prerequisites = "none"

        # if LISP courses are formatted as, for example, LISP 5A, 5B, 5C, then make separate courses for each of them
        if 'LISP' in course_code and len(course_code.split()) != 2:
            for num in course_code.split()[1:]:
                num = num.strip(',')
                course_code = course_dept + " " + num
                course_info.append([course_code, course_dept, course_title, course_units, course_description, course_prerequisites])

        # if course codes contain - or /
    #         elif len(course_code.split('-') != 1):
    #             course
        else:
            course_info.append([course_code, course_dept, course_title, course_units, course_description, course_prerequisites])
# Out:
# https://catalog.ucsd.edu/courses/AIP.html
# https://catalog.ucsd.edu/courses/AASM.html
# https://catalog.ucsd.edu/courses/AWP.html
# https://catalog.ucsd.edu/courses/ANTH.html
# https://catalog.ucsd.edu/courses/AAPI.html
# https://catalog.ucsd.edu/courses/AUDL.html
# https://catalog.ucsd.edu/courses/BIOI.html
# https://catalog.ucsd.edu/courses/BIOL.html
# https://catalog.ucsd.edu/courses/BIOM.html
# https://catalog.ucsd.edu/courses/CHEM.html
# https://catalog.ucsd.edu/courses/CLS.html
# https://catalog.ucsd.edu/courses/CHIN.html
# https://catalog.ucsd.edu/courses/CLAS.html
# https://catalog.ucsd.edu/courses/CCS.html
# https://catalog.ucsd.edu/courses/CSP.html
# https://catalog.ucsd.edu/courses/CLIN.html
# https://catalog.ucsd.edu/courses/CLRE.html
# https://catalog.ucsd.edu/courses/COGS.html
# https://catalog.ucsd.edu/courses/COMM.html
# https://catalog.ucsd.edu/courses/css.html
# https://catalog.ucsd.edu/courses/CGS.html
# https://catalog.ucsd.edu/courses/CAT.html
# https://catalog.ucsd.edu/courses/DSC.html
# https://catalog.ucsd.edu/courses/DSGN.html
# https://catalog.ucsd.edu/courses/DOC.html
# https://catalog.ucsd.edu/courses/ECON.html
# https://catalog.ucsd.edu/courses/EDS.html
# https://catalog.ucsd.edu/courses/ERC.html
# https://catalog.ucsd.edu/courses/ENG.html
# https://catalog.ucsd.edu/courses/BENG.html
# https://catalog.ucsd.edu/courses/CSE.html
# https://catalog.ucsd.edu/courses/ECE.html
# https://catalog.ucsd.edu/courses/MAS.html
# https://catalog.ucsd.edu/courses/MAE-AESE.html
# https://catalog.ucsd.edu/courses/MAE.html
# https://catalog.ucsd.edu/courses/NANO.html
# https://catalog.ucsd.edu/courses/SE.html
# https://catalog.ucsd.edu/courses/ENVR.html
# https://catalog.ucsd.edu/courses/ESYS.html
# https://catalog.ucsd.edu/courses/ETHN.html
# https://catalog.ucsd.edu/courses/FILM.html
# https://catalog.ucsd.edu/courses/GLBH.html
# https://catalog.ucsd.edu/courses/GPS.html
# https://catalog.ucsd.edu/courses/GSS.html
# https://catalog.ucsd.edu/courses/LHCO.html
# https://catalog.ucsd.edu/courses/HIST.html
# https://catalog.ucsd.edu/courses/HDS.html
# https://catalog.ucsd.edu/courses/HMNR.html
# https://catalog.ucsd.edu/courses/HUM.html
# https://catalog.ucsd.edu/courses/INTL.html
# https://catalog.ucsd.edu/courses/JAPN.html
# https://catalog.ucsd.edu/courses/JWSP.html
# https://catalog.ucsd.edu/courses/LATI.html
# https://catalog.ucsd.edu/courses/LAWS.html
# https://catalog.ucsd.edu/courses/LING.html
# https://catalog.ucsd.edu/courses/LIT.html
# https://catalog.ucsd.edu/courses/MMW.html
# https://catalog.ucsd.edu/courses/MGT.html
# https://catalog.ucsd.edu/courses/MBC.html
# https://catalog.ucsd.edu/courses/MATS.html
# https://catalog.ucsd.edu/courses/MATH.html
# https://catalog.ucsd.edu/courses/MSED.html
# https://catalog.ucsd.edu/courses/MCWP.html
# https://catalog.ucsd.edu/courses/MUS.html
# https://catalog.ucsd.edu/courses/NEU.html
# https://catalog.ucsd.edu/courses/PHIL.html
# https://catalog.ucsd.edu/courses/PHYS.html
# https://catalog.ucsd.edu/courses/POLI.html
# https://catalog.ucsd.edu/courses/PSYC.html
# https://catalog.ucsd.edu/courses/FMPH.html
# https://catalog.ucsd.edu/courses/RELI.html
# https://catalog.ucsd.edu/courses/REV.html
# https://catalog.ucsd.edu/courses/SCIS.html
# https://catalog.ucsd.edu/courses/SIO.html
# https://catalog.ucsd.edu/courses/SEV.html
# https://catalog.ucsd.edu/courses/SXTH.html
# https://catalog.ucsd.edu/courses/SOC.html
# https://catalog.ucsd.edu/courses/SYN.html
# https://catalog.ucsd.edu/courses/THEA.html
# https://catalog.ucsd.edu/courses/TMC.html
# https://catalog.ucsd.edu/courses/USP.html
# https://catalog.ucsd.edu/courses/VIS.html
# https://catalog.ucsd.edu/courses/WARR.html

# %%
course_info_df = pd.DataFrame(course_info, columns=['Code', 'Department', 'Title', 'Units', 'Description', 'Prerequisites'])
course_info_df
# Out:
#            Code Department                                           Title  \
# 0        AIP 97        AIP                             Academic Internship
# 1       AIP 197        AIP                     Academic Internship Program
# 2     AIP 197DC        AIP                 UCDC: Washington, DC Internship
# 3      AIP 197P        AIP                       Public Service Internship
# 4      AIP 197T        AIP    Academic Internship Program—Special Programs
# ...         ...        ...                                             ...
# 7029   WCWP 100       WCWP                                Academic Writing
# 7030   WCWP 160       WCWP  Technical Writing for Scientists and Engineers
# 7031   WARR 189       WARR      Academic Mentoring and the Writing Process
# 7032   WCWP 198       WCWP                                     Group Study
# 7033   WCWP 500       WCWP                     Apprentice Teaching in WCWP
#
#                    Units                                        Description  \
# 0                   2, 4  Individual placements for field learning. Must...
# 1     2, 4, 6, 8, 10, 12  Individual internship placements integrated wi...
# 2               6, 8, 10  This internship is attached to the University ...
# 3               4, 8, 12  Individual placements for field learning perfo...
# 4                      2  Individual placements for field learning assoc...
# ...                  ...                                                ...
# 7029                   4  An upper-division workshop course in argumenta...
# 7030                   4  An upper-division workshop-style writing cours...
# 7031                   2  Students will gain a fundamental understanding...
# 7032                   2  A directed group study involving research and ...
# 7033              2 or 4  Consideration of pedagogical methods appropria...
#
#                                           Prerequisites
# 0     lower-division standing, completion of thirty ...
# 1         upper-division standing; department approval.
# 2         upper-division standing; department approval.
# 3     ninety units completed; 2.5 minimum cumulative...
# 4     ninety units minimum completed; 2.5 minimum cu...
# ...                                                 ...
# 7029  junior/senior standing and must be a Warren Co...
# 7030                            junior/senior standing.
# 7031    permission of instructor is required to enroll.
# 7032                                               none
# 7033                                 graduate standing.
#
# [7034 rows x 6 columns]

# %%
def check_code(code):
    if '/' in code or '-' in code:
        print(code)

# %%
course_info_df.to_csv('data/course_catalog.csv')

# %% [markdown]
# ## Dataset 3: UCSD Schedule of Classes
# - Scraped for Winter 2024 because Spring 2024 is not available yet

# %%
def get_subject_links(main_page_url):
    response = requests.get(main_page_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the "Subjects" section
    # This depends on the structure of the main page
    # Adjust the selector as per the actual HTML structure
    subject_section = soup.find('div', {'id': 'subject_Panel'}) 

    subject_links = []
    if subject_section:
        links = subject_section.find_all('a')
        for link in links:
            href = link.get('href')
            if href and href.startswith('courseList.aspx?name=') and not href.endswith('dept=true'):
                full_link = main_page_url + href
                subject_links.append(full_link)

    return subject_links

# %%
def get_courses_from_subject(subject_url):
    response = requests.get(subject_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the section under "Select your Course:" header
    course_section = soup.find('h3', text='Select your Course:').find_next_sibling('ul')

    # Find all links within this section
    course_links = course_section.find_all('a') if course_section else []
    
    course_list = []
    for course in course_links:
        if 'coursemain' in course.get('href'):
            course = ' '.join(course.text.split()[:2])
            course_list.append(course)
    
    return list(set(course_list))

# %%
starting_letters = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'L', 'M', 'N', 'O', 'P', 'R', 'S', 'T', 'U', 'V', 'W']
all_courses = []

# for each possible starting letter of the subjects
for letter in starting_letters:
    main_page_url = "https://courses.ucsd.edu/?u_letter=" + letter
    
    print(letter)
    
    # get all subjects starting with the letter
    subject_links = get_subject_links(main_page_url)
    
    # for each subject
    for subject_link in subject_links:
        subject_name = subject_link.split('=')[-1]
        
        # get all courses in that subject
        courses = get_courses_from_subject('https://courses.ucsd.edu/courseList.aspx?name=' + subject_name)
        all_courses += courses
# Out:
# A
# B
# C
# D
# E
# F
# G
# H
# I
# J
# L
# M
# N
# O
# P
# R
# S
# T
# U
# V
# W

# %%
len(all_courses)
# Out:
# 2297

# %%
all_courses
# Out:
# ['AAS 10',
#  'AAS 11',
#  'AESE 279A',
#  'AESE 278C',
#  'AESE 241',
#  'AESE 278B',
#  'AIP 197P',
#  'AIP 197',
#  'AIP 197DC',
#  'ANAR 135',
#  'ANAR 121',
#  'ANAR 117',
#  'ANAR 100',
#  'ANAR 156',
#  'ANAR 167',
#  'ANBI 100',
#  'ANBI 134',
#  'ANBI 112',
#  'ANBI 136',
#  'ANBI 159',
#  'ANBI 120',
#  'ANBI 116',
#  'ANBI 143',
#  'ANES 299',
#  'ANES 402',
#  'ANES 403',
#  'ANES 401',
#  'ANES 296',
#  'ANES 410',
#  'ANES 496',
#  'ANSC 135',
#  'ANSC 164',
#  'ANSC 173',
#  'ANSC 139',
#  'ANSC 148',
#  'ANSC 184',
#  'ANSC 188',
#  'ANSC 100',
#  'ANSC 150',
#  'ANSC 125',
#  'ANSC 122',
#  'ANTH 246',
#  'ANTH 260',
#  'ANTH 23',
#  'ANTH 273',
#  'ANTH 281B',
#  'ANTH 202',
#  'ANTH 269',
#  'ANTH 200',
#  'ANTH 5',
#  'ANTH 500',
#  'ANTH 296',
#  'ANTH 196B',
#  'ANTH 280C',
#  'ANTH 45',
#  'ANTH 110',
#  'ANTH 280B',
#  'ANTH 298',
#  'ANTH 230',
#  'ANTH 106',
#  'ANTH 128A',
#  'ANTH 299',
#  'ANTH 279',
#  'ANTH 295',
#  'ANTH 107',
#  'ANTH 21',
#  'ANTH 87',
#  'ANTH 102',
#  'ANTH 111',
#  'AUD 291',
#  'AUD 284',
#  'AUD 236',
#  'AUD 276',
#  'AUD 263',
#  'AUD 278',
#  'AUD 296',
#  'AUD 298',
#  'AUD 299',
#  'AWP 3',
#  'AWP 10R',
#  'AWP 4A',
#  'BENG 119B',
#  'BENG 187C',
#  'BENG 148B',
#  'BENG 179B',
#  'BENG 278',
#  'BENG 202',
#  'BENG 130',
#  'BENG 123',
#  'BENG 294B',
#  'BENG 191',
#  'BENG 230B',
#  'BENG 139B',
#  'BENG 120',
#  'BENG 168',
#  'BENG 147B',
#  'BENG 103B',
#  'BENG 212',
#  'BENG 99H',
#  'BENG 281',
#  'BENG 126B',
#  'BENG 112A',
#  'BENG 140A',
#  'BENG 238',
#  'BENG 127B',
#  'BENG 161B',
#  'BENG 169B',
#  'BENG 128B',
#  'BENG 226',
#  'BENG 247B',
#  'BENG 149B',
#  'BENG 186B',
#  'BENG 225',
#  'BENG 152',
#  'BENG 196',
#  'BENG 501',
#  'BENG 129B',
#  'BENG 223',
#  'BENG 207',
#  'BENG 241B',
#  'BENG 292',
#  'BENG 299',
#  'BENG 291',
#  'BENG 1',
#  'BENG 181',
#  'BENG 298L',
#  'BENG 199',
#  'BGGN 237',
#  'BGGN 209',
#  'BGGN 246A',
#  'BGGN 293',
#  'BGGN 298',
#  'BGGN 228',
#  'BGGN 280',
#  'BGGN 299',
#  'BGGN 270',
#  'BGGN 207',
#  'BGGN 254',
#  'BGGN 285',
#  'BGGN 284',
#  'BGGN 206B',
#  'BGGN 290',
#  'BGGN 225',
#  'BGGN 271',
#  'BGGN 500',
#  'BGGN 211',
#  'BGGN 241',
#  'BGGN 253',
#  'BGGN 213',
#  'BGGN 249B',
#  'BGGN 283',
#  'BGGN 282',
#  'BGGN 227',
#  'BGJC 215',
#  'BGJC 204',
#  'BGRD 200',
#  'BGSE 205',
#  'BGSE 200',
#  'BIBC 194',
#  'BIBC 103',
#  'BIBC 100',
#  'BIBC 102',
#  'BICD 110',
#  'BICD 145',
#  'BICD 136',
#  'BICD 100',
#  'BIEB 152',
#  'BIEB 150',
#  'BIEB 140',
#  'BIEB 134',
#  'BIEB 128',
#  'BIEB 121',
#  'BIEB 166',
#  'BIEB 123',
#  'BIEB 194',
#  'BILD 87',
#  'BILD 26',
#  'BILD 2',
#  'BILD 62',
#  'BILD 4',
#  'BILD 12',
#  'BILD 22',
#  'BILD 99H',
#  'BILD 61',
#  'BILD 60',
#  'BILD 81',
#  'BILD 99',
#  'BILD 1',
#  'BILD 3',
#  'BILD 5',
#  'BIMM 114',
#  'BIMM 134',
#  'BIMM 121',
#  'BIMM 172',
#  'BIMM 101',
#  'BIMM 110',
#  'BIMM 100',
#  'BIMM 143',
#  'BIMM 181',
#  'BIMM 194',
#  'BIMM 120',
#  'BIOM 253',
#  'BIOM 218',
#  'BIOM 202',
#  'BIOM 255',
#  'BIOM 275',
#  'BIOM 277',
#  'BIOM 246',
#  'BIOM 200C',
#  'BIOM 295',
#  'BIOM 299',
#  'BIOM 288',
#  'BIOM 262',
#  'BIOM 203B',
#  'BIOM 242',
#  'BIOM 298',
#  'BIOM 256',
#  'BIPN 100',
#  'BIPN 134',
#  'BIPN 145',
#  'BIPN 154',
#  'BIPN 102',
#  'BIPN 105',
#  'BIPN 160',
#  'BIPN 108',
#  'BIPN 194',
#  'BIPN 140',
#  'BISP 182',
#  'BISP 193',
#  'BISP 194',
#  'BISP 197',
#  'BISP 195',
#  'BISP 199',
#  'BNFO 298',
#  'BNFO 294',
#  'BNFO 281',
#  'BNFO 299',
#  'BNFO 262',
#  'BNFO 500',
#  'BNFO 283',
#  'CAT 500',
#  'CAT 125R',
#  'CAT 2CE',
#  'CAT 124',
#  'CAT 2',
#  'CAT 125',
#  'CCE 1',
#  'CCS 102',
#  'CCS 123',
#  'CENG 299',
#  'CENG 102',
#  'CENG 213',
#  'CENG 101B',
#  'CENG 134',
#  'CENG 221B',
#  'CENG 215',
#  'CENG 252',
#  'CENG 101A',
#  'CENG 15',
#  'CENG 124A',
#  'CENG 205',
#  'CENG 114',
#  'CENG 199',
#  'CENG 251',
#  'CENG 256',
#  'CENG 176A',
#  'CGS 199',
#  'CGS 119',
#  'CGS 105',
#  'CGS 2B',
#  'CGS 101',
#  'CGS 108',
#  'CGS 125',
#  'CGS 196A',
#  'CGS 123',
#  'CGS 111',
#  'CGS 113',
#  'CGS 500',
#  'CGS 299',
#  'CHEM 291',
#  'CHEM 264',
#  'CHEM 172',
#  'CHEM 254',
#  'CHEM 168',
#  'CHEM 229',
#  'CHEM 7L',
#  'CHEM 120A',
#  'CHEM 6A',
#  'CHEM 40B',
#  'CHEM 212',
#  'CHEM 126B',
#  'CHEM 143B',
#  'CHEM 227',
#  'CHEM 294',
#  'CHEM 6B',
#  'CHEM 199',
#  'CHEM 6C',
#  'CHEM 40A',
#  'CHEM 41A',
#  'CHEM 158',
#  'CHEM 1',
#  'CHEM 155',
#  'CHEM 255',
#  'CHEM 258',
#  'CHEM 219C',
#  'CHEM 100B',
#  'CHEM 41B',
#  'CHEM 134',
#  'CHEM 223',
#  'CHEM 100A',
#  'CHEM 299',
#  'CHEM 131',
#  'CHEM 105A',
#  'CHEM 164',
#  'CHEM 11',
#  'CHEM 114C',
#  'CHEM 200B',
#  'CHEM 261',
#  'CHEM 6BH',
#  'CHEM 114B',
#  'CHEM 187',
#  'CHEM 262',
#  'CHEM 280',
#  'CHEM 115',
#  'CHEM 231',
#  'CHEM 232A',
#  'CHEM 215',
#  'CHEM 108',
#  'CHEM 151',
#  'CHEM 114A',
#  'CHEM 213B',
#  'CHEM 298',
#  'CHEM 109',
#  'CHEM 194',
#  'CHEM 43A',
#  'CHEM 154',
#  'CHIN 100BN',
#  'CHIN 182A',
#  'CHIN 169A',
#  'CHIN 100BM',
#  'CHIN 500',
#  'CHIN 10BN',
#  'CHIN 20BD',
#  'CHIN 10BM',
#  'CHIN 10BD',
#  'CHIN 20BN',
#  'CLAS 196B',
#  'CLAS 87',
#  'CLAS 109',
#  'CLAS 196A',
#  'CLIN 227B',
#  'CLIN 228',
#  'CLIN 296',
#  'CLIN 294B',
#  'CLIN 227A',
#  'CLRE 259',
#  'CLRE 263',
#  'CLRE 236R',
#  'CLRE 237',
#  'CLRE 297',
#  'CLRE 253',
#  'CLRE 250R',
#  'CLRE 260',
#  'CLRE 234',
#  'CLRE 295B',
#  'CMM 246',
#  'COGR 201D',
#  'COGR 280',
#  'COGR 294',
#  'COGR 500',
#  'COGR 225C',
#  'COGR 298',
#  'COGR 275',
#  'COGR 299',
#  'COGR 200C',
#  'COGR 225D',
#  'COGS 181',
#  'COGS 118C',
#  'COGS 500',
#  'COGS 211B',
#  'COGS 9',
#  'COGS 194',
#  'COGS 123',
#  'COGS 200',
#  'COGS 99H',
#  'COGS 199',
#  'COGS 193',
#  'COGS 118B',
#  'COGS 195',
#  'COGS 111',
#  'COGS 101A',
#  'COGS 197',
#  'COGS 101B',
#  'COGS 187B',
#  'COGS 190B',
#  'COGS 108',
#  'COGS 2',
#  'COGS 229',
#  'COGS 260',
#  'COGS 18',
#  'COGS 160',
#  'COGS 290',
#  'COGS 17',
#  'COGS 210B',
#  'COGS 156',
#  'COGS 10',
#  'COGS 198',
#  'COGS 165',
#  'COGS 172',
#  'COGS 298',
#  'COGS 13',
#  'COGS 14A',
#  'COGS 163',
#  'COGS 205',
#  'COGS 87',
#  'COGS 177',
#  'COGS 1',
#  'COGS 8',
#  'COGS 100',
#  'COGS 14B',
#  'COGS 107B',
#  'COGS 150',
#  'COGS 153',
#  'COGS 299',
#  'COGS 11',
#  'COGS 164',
#  'COMM 111B',
#  'COMM 106F',
#  'COMM 127',
#  'COMM 140',
#  'COMM 101N',
#  'COMM 109N',
#  'COMM 100B',
#  'COMM 115',
#  'COMM 80',
#  'COMM 180',
#  'COMM 114T',
#  'COMM 10',
#  'COMM 124A',
#  'COMM 101A',
#  'COMM 101D',
#  'COMM 194',
#  'COMM 196B',
#  'COMM 111G',
#  'COMM 101K',
#  'COMM 20',
#  'COMM 171',
#  'COMM 190',
#  'COMM 109D',
#  'COMM 158',
#  'COMM 101',
#  'COMM 160',
#  'COMM 113T',
#  'COMM 102C',
#  'COMM 139',
#  'COMM 102B',
#  'COMM 131',
#  'COMM 108D',
#  'CSE 169',
#  'CSE 210',
#  'CSE 191',
#  'CSE 90',
#  'CSE 151B',
#  'CSE 202',
#  'CSE 8B',
#  'CSE 219',
#  'CSE 30',
#  'CSE 197',
#  'CSE 95',
#  'CSE 257',
#  'CSE 251U',
#  'CSE 123',
#  'CSE 15L',
#  'CSE 284',
#  'CSE 11',
#  'CSE 599',
#  'CSE 99H',
#  'CSE 190',
#  'CSE 232B',
#  'CSE 282',
#  'CSE 290',
#  'CSE 87',
#  'CSE 142',
#  'CSE 152A',
#  'CSE 198',
#  'CSE 105',
#  'CSE 199',
#  'CSE 299',
#  'CSE 207A',
#  'CSE 12',
#  'CSE 100R',
#  'CSE 160',
#  'CSE 140L',
#  'CSE 272',
#  'CSE 273',
#  'CSE 120',
#  'CSE 203B',
#  'CSE 127',
#  'CSE 21',
#  'CSE 107',
#  'CSE 148',
#  'CSE 251A',
#  'CSE 91',
#  'CSE 252B',
#  'CSE 270',
#  'CSE 151A',
#  'CSE 229A',
#  'CSE 291',
#  'CSE 240A',
#  'CSE 6R',
#  'CSE 101',
#  'CSE 229C',
#  'CSE 239B',
#  'CSE 280A',
#  'CSE 132A',
#  'CSE 142L',
#  'CSE 167',
#  'CSE 110',
#  'CSE 206A',
#  'CSE 251B',
#  'CSE 500',
#  'CSE 221',
#  'CSE 130',
#  'CSE 140',
#  'CSE 234',
#  'CSE 294',
#  'CSE 293',
#  'CSE 240B',
#  'CSE 181',
#  'CSE 132C',
#  'CSE 298',
#  'CSE 8A',
#  'CSE 20',
#  'CSS 205',
#  'CSS 296',
#  'CSS 2',
#  'CSS 209',
#  'CSS 1',
#  'DDPM 213',
#  'DDPM 208',
#  'DDPM 204',
#  'DERM 436',
#  'DERM 428',
#  'DERM 296',
#  'DERM 299',
#  'DOC 2',
#  'DOC 500',
#  'DSC 10',
#  'DSC 197',
#  'DSC 40B',
#  'DSC 30',
#  'DSC 155',
#  'DSC 293',
#  'DSC 291',
#  'DSC 215',
#  'DSC 148',
#  'DSC 241',
#  'DSC 80',
#  'DSC 140A',
#  'DSC 190',
#  'DSC 294',
#  'DSC 102',
#  'DSC 240',
#  'DSC 140B',
#  'DSC 100',
#  'DSC 208R',
#  'DSC 170',
#  'DSC 211',
#  'DSC 261',
#  'DSC 40A',
#  'DSC 99',
#  'DSC 106',
#  'DSC 500',
#  'DSC 288R',
#  'DSC 96',
#  'DSC 212',
#  'DSC 299',
#  'DSC 180B',
#  'DSC 20',
#  'DSC 204A',
#  'DSC 206',
#  'DSC 266R',
#  'DSC 260',
#  'DSC 255R',
#  'DSC 161',
#  'DSE 260A',
#  'DSE 210',
#  'DSE 201',
#  'DSE 241',
#  'DSGN 160',
#  'DSGN 195',
#  'DSGN 2',
#  'DSGN 118',
#  'DSGN 100',
#  'DSGN 119',
#  'DSGN 1',
#  'ECE 264D',
#  'ECE 226',
#  'ECE 65',
#  'ECE 264A',
#  'ECE 271B',
#  'ECE 175A',
#  'ECE 299',
#  'ECE 25',
#  'ECE 198',
#  'ECE 200',
#  'ECE 260B',
#  'ECE 257B',
#  'ECE 107',
#  'ECE 191',
#  'ECE 197',
#  'ECE 121B',
#  'ECE 111',
#  'ECE 265D',
#  'ECE 250',
#  'ECE 109',
#  'ECE 103',
#  'ECE 15',
#  'ECE 276A',
#  'ECE 199',
#  'ECE 159',
#  'ECE 172A',
#  'ECE 269',
#  'ECE 16',
#  'ECE 150',
#  'ECE 161B',
#  'ECE 222B',
#  'ECE 102',
#  'ECE 212BN',
#  'ECE 251A',
#  'ECE 125A',
#  'ECE 5',
#  'ECE 184',
#  'ECE 265A',
#  'ECE 285',
#  'ECE 240A',
#  'ECE 143',
#  'ECE 298',
#  'ECE 128B',
#  'ECE 230B',
#  'ECE 247B',
#  'ECE 140A',
#  'ECE 141A',
#  'ECE 501',
#  'ECE 241B',
#  'ECE 135B',
#  'ECE 258A',
#  'ECE 202',
#  'ECE 284',
#  'ECE 290',
#  'ECE 181',
#  'ECE 176',
#  'ECE 238B',
#  'ECE 101',
#  'ECE 277',
#  'ECE 45',
#  'ECE 35',
#  'ECON 245',
#  'ECON 120B',
#  'ECON 110BH',
#  'ECON 246',
#  'ECON 195',
#  'ECON 100B',
#  'ECON 220E',
#  'ECON 299',
#  'ECON 178',
#  'ECON 100C',
#  'ECON 110A',
#  'ECON 220B',
#  'ECON 3',
#  'ECON 100A',
#  'ECON 120C',
#  'ECON 151',
#  'ECON 190',
#  'ECON 250B',
#  'ECON 237',
#  'ECON 116',
#  'ECON 4',
#  'ECON 200B',
#  'ECON 113',
#  'ECON 264',
#  'ECON 233',
#  'ECON 281',
#  'ECON 109',
#  'ECON 140',
#  'ECON 120BH',
#  'ECON 110B',
#  'ECON 171',
#  'ECON 210B',
#  'ECON 136',
#  'ECON 145',
#  'ECON 120A',
#  'ECON 1',
#  'ECON 284',
#  'ECON 5',
#  'ECON 138',
#  'ECON 149',
#  'ECON 183',
#  'ECON 2',
#  'EDS 369B',
#  'EDS 130',
#  'EDS 369A',
#  'EDS 205A',
#  'EDS 115',
#  'EDS 124AR',
#  'EDS 128A',
#  'EDS 124BR',
#  'EDS 287C',
#  'EDS 114',
#  'EDS 259B',
#  'EDS 190',
#  'EDS 379B',
#  'EDS 180',
#  'EDS 370A',
#  'EDS 117',
#  'EDS 294A',
#  'EDS 355B',
#  'EDS 299',
#  'EDS 126',
#  'EDS 280',
#  'EDS 252',
#  'EDS 381',
#  'EDS 287A',
#  'EDS 254',
#  'EDS 23',
#  'EDS 195',
#  'EDS 129B',
#  'EDS 290',
#  'EDS 87',
#  'EDS 111',
#  'EDS 122',
#  'EDS 103',
#  'EDS 39',
#  'EDS 259A',
#  'EDS 296',
#  'EDS 289A',
#  'EDS 324BR',
#  'EDS 370B',
#  'EDS 291A',
#  'EDS 352B',
#  'EDS 131',
#  'EDS 118',
#  'EDS 119',
#  'EDS 139',
#  'EDS 265',
#  'EDS 380B',
#  'EDS 293A',
#  'EDS 297',
#  'EDS 288B',
#  'EDS 140',
#  'EDS 361B',
#  'EDS 133',
#  'EDS 125',
#  'EMED 425',
#  'EMED 427',
#  'EMED 299',
#  'EMED 473',
#  'EMED 296',
#  'EMED 411',
#  'EMED 420',
#  'EMED 496',
#  'EMED 423',
#  'ENG 100D',
#  'ENG 10',
#  'ENG 100DR',
#  'ENG 15',
#  'ENG 100L',
#  'ENVR 152',
#  'ENVR 120',
#  'ENVR 141',
#  'ENVR 110',
#  'ERC 89',
#  'ERC 2',
#  'ERC 20',
#  'ESYS 187B',
#  'ESYS 102',
#  'ETHN 164',
#  'ETHN 299',
#  'ETHN 163E',
#  'ETHN 154',
#  'ETHN 2R',
#  'ETHN 114A',
#  'ETHN 200B',
#  'ETHN 198',
#  'ETHN 500',
#  'ETHN 101',
#  'ETHN 116',
#  'ETHN 298',
#  'ETHN 103',
#  'ETHN 170',
#  'ETHN 179',
#  'ETHN 100B',
#  'ETHN 230',
#  'ETHN 138',
#  'ETHN 214A',
#  'ETHN 100H',
#  'ETHN 104',
#  'ETHN 123',
#  'ETHN 201',
#  'ETHN 112A',
#  'ETIM 289',
#  'EXPR 205',
#  'EXPR 201',
#  'EXPR 100',
#  'EXPR 105',
#  'FILM 87',
#  'FMPH 194',
#  'FMPH 404',
#  'FMPH 40',
#  'FMPH 50',
#  'FMPH 299',
#  'FMPH 460',
#  'FMPH 241',
#  'FMPH 496B',
#  'FMPH 405',
#  'FMPH 499',
#  'FMPH 222',
#  'FMPH 130',
#  'FMPH 491',
#  'FMPH 102',
#  'FMPH 243B',
#  'FMPH 412',
#  'FMPH 226',
#  'FMPH 110',
#  'FMPH 291',
#  'FMPH 244B',
#  'FMPH 495',
#  'FMPH 498',
#  'FMPH 161',
#  'FMPH 290',
#  'FMPH 277',
#  'FMPH 193',
#  'FMPH 425',
#  'FMPH 95',
#  'FMPH 419',
#  'FMPH 440',
#  'FMPH 411',
#  'FMPH 101',
#  'FMPH 428',
#  'FMPH 120',
#  'FMPH 199',
#  'FMPH 191',
#  'FMPH 415',
#  'FPM 428',
#  'FPM 431',
#  'FPM 410',
#  'FPM 297',
#  'FPM 411',
#  'FPM 412',
#  'FPM 432',
#  'FPM 441',
#  'FPM 280B',
#  'FPM 426',
#  'FPM 259B',
#  'FPM 496',
#  'FPM 413',
#  'FPM 299',
#  'FPM 442',
#  'FPM 419',
#  'FPM 258B',
#  'FPM 296',
#  'GLBH 108',
#  'GLBH 299',
#  'GLBH 111',
#  'GLBH 150A',
#  'GLBH 160',
#  'GLBH 150',
#  'GLBH 148',
#  'GLBH 104',
#  'GLBH 201',
#  'GLBH 113',
#  'GLBH 214',
#  'GLBH 139',
#  'GLBH 181',
#  'GLBH 249',
#  'GLBH 20',
#  'GLBH 102',
#  'GPCO 404',
#  'GPCO 400',
#  'GPCO 468',
#  'GPCO 470',
#  'GPCO 415',
#  'GPCO 462',
#  'GPCO 454',
#  'GPEC 485',
#  'GPEC 416',
#  'GPEC 444',
#  'GPEC 431',
#  'GPEC 462',
#  'GPEC 486',
#  'GPEC 451',
#  'GPGN 499',
#  'GPGN 490',
#  'GPGN 497',
#  'GPIM 470',
#  'GPIM 452',
#  'GPLA 441B',
#  'GPLA 411B',
#  'GPPA 430',
#  'GPPA 470',
#  'GPPA 460',
#  'GPPA 463',
#  'GPPS 443',
#  'GPPS 454',
#  'GPPS 401',
#  'GPPS 428',
#  'GPPS 438',
#  'GPPS 409',
#  'GPPS 469',
#  'GPPS 407',
#  'GPPS 441',
#  'GPPS 423',
#  'GSS 22',
#  'GSS 27',
#  'HDS 181',
#  'HDS 60',
#  'HDS 191',
#  'HDS 150',
#  'HDS 95',
#  'HDS 133',
#  'HDS 110',
#  'HIAF 112',
#  'HIAF 111',
#  'HIEA 115',
#  'HIEA 124',
#  'HIEA 138',
#  'HIEU 109',
#  'HIEU 116C',
#  'HIEU 102',
#  'HIEU 108',
#  'HIGR 215B',
#  'HIGR 281',
#  'HIGR 241',
#  'HIGR 208',
#  'HIGR 275B',
#  'HIGR 500',
#  'HIGR 211',
#  'HIGR 299',
#  'HIGR 298',
#  'HIGR 240',
#  'HILA 118',
#  'HILA 102',
#  'HILA 144',
#  'HILD 2B',
#  'HILD 11',
#  'HILD 42',
#  'HILD 7B',
#  'HILD 60',
#  'HILD 14',
#  'HINE 129',
#  'HINE 109',
#  'HINE 116',
#  'HISC 106',
#  'HISC 180',
#  'HITO 100',
#  'HITO 119',
#  'HITO 141',
#  'HITO 133',
#  'HITO 195',
#  'HITO 193',
#  'HITO 178',
#  'HITO 87',
#  'HIUS 133',
#  'HIUS 108A',
#  'HIUS 123',
#  'HIUS 152B',
#  'HIUS 113',
#  'HIUS 102',
#  'HIUS 149',
#  'HMNR 100',
#  'HUM 1',
#  'HUM 2',
#  'HUM 4',
#  'INTL 101',
#  'INTL 190',
#  'INTL 102',
#  'JAPN 196A',
#  'JAPN 20B',
#  'JAPN 135B',
#  'JAPN 500',
#  'JAPN 140B',
#  'JAPN 150B',
#  'JAPN 10BR',
#  'JAPN 10B',
#  'JAPN 190',
#  'JAPN 130B',
#  'JWSP 104',
#  'JWSP 2',
#  'JWSP 500',
#  'LATI 298',
#  'LATI 50',
#  'LATI 170',
#  'LATI 140',
#  'LATI 10',
#  'LATI 299',
#  'LAWS 101',
#  'LIAB 1B',
#  'LIAB 1EX',
#  'LIAB 1E',
#  'LIAB 1BX',
#  ...]

# %%
# Exporting Winter 2024 courses to a csv file
pd.DataFrame(all_courses, columns=['Course']).to_csv('data/winter2024.csv')
