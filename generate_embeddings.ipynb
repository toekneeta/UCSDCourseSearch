# %%
from FlagEmbedding import FlagModel

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

import numpy as np
import re
import time
import gzip
import pandas as pd
import heapq
import json

# %%
# if you haven't downloaded stopwords or wordnet before, uncomment the lines below and run them
# nltk.download('stopwords')
# nltk.download('wordnet')

# %% [markdown]
# ## Step 0: Read in the data

# %%
course_catalog = pd.read_csv('data/course_catalog.csv')
course_catalog
# Out:
#            Code Department                                           Title  \
# 0        AIP 97        AIP                             Academic Internship
# 1       AIP 197        AIP                     Academic Internship Program
# 2     AIP 197DC        AIP                 UCDC: Washington, DC Internship
# 3      AIP 197P        AIP                       Public Service Internship
# 4      AIP 197T        AIP    Academic Internship Program—Special Programs
# ...         ...        ...                                             ...
# 7164   WCWP 100       WCWP                                Academic Writing
# 7165   WCWP 160       WCWP  Technical Writing for Scientists and Engineers
# 7166   WARR 189       WARR      Academic Mentoring and the Writing Process
# 7167   WCWP 198       WCWP                                     Group Study
# 7168   WCWP 500       WCWP                     Apprentice Teaching in WCWP
#
#                    Units                                        Description  \
# 0                   2, 4  Individual placements for field learning. Must...
# 1     2, 4, 6, 8, 10, 12  Individual internship placements integrated wi...
# 2               6, 8, 10  This internship is attached to the University ...
# 3               4, 8, 12  Individual placements for field learning perfo...
# 4                      2  Individual placements for field learning assoc...
# ...                  ...                                                ...
# 7164                   4  An upper-division workshop course in argumenta...
# 7165                   4  An upper-division workshop-style writing cours...
# 7166                   2  Students will gain a fundamental understanding...
# 7167                   2  A directed group study involving research and ...
# 7168              2 or 4  Consideration of pedagogical methods appropria...
#
#                                           Prerequisites           Level  \
# 0     lower-division standing, completion of thirty ...  Lower Division
# 1         upper-division standing; department approval.  Upper Division
# 2         upper-division standing; department approval.  Upper Division
# 3     ninety units completed; 2.5 minimum cumulative...  Upper Division
# 4     ninety units minimum completed; 2.5 minimum cu...  Upper Division
# ...                                                 ...             ...
# 7164  junior/senior standing and must be a Warren Co...  Upper Division
# 7165                            junior/senior standing.  Upper Division
# 7166    permission of instructor is required to enroll.  Upper Division
# 7167                                               none  Upper Division
# 7168                                 graduate standing.        Graduate
#
#                                                     URL
# 0     https://cape.ucsd.edu/responses/Results.aspx?N...
# 1     https://cape.ucsd.edu/responses/Results.aspx?N...
# 2     https://cape.ucsd.edu/responses/Results.aspx?N...
# 3     https://cape.ucsd.edu/responses/Results.aspx?N...
# 4     https://cape.ucsd.edu/responses/Results.aspx?N...
# ...                                                 ...
# 7164  https://cape.ucsd.edu/responses/Results.aspx?N...
# 7165  https://cape.ucsd.edu/responses/Results.aspx?N...
# 7166  https://cape.ucsd.edu/responses/Results.aspx?N...
# 7167  https://cape.ucsd.edu/responses/Results.aspx?N...
# 7168  https://cape.ucsd.edu/responses/Results.aspx?N...
#
# [7169 rows x 8 columns]

# %%
def preprocess(text):
     # Convert to lowercase
    text = text.lower()
    
    # Tokenizes text
    tokens = re.split(r'[^a-zA-Z0-9]+', text)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    
    # Lemmatize
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    return ' '.join(tokens)

# %%
start = time.time()
course_catalog_preprocessed = course_catalog.assign(Preprocessed_Title=course_catalog['Title'].apply(preprocess))
course_catalog_preprocessed = course_catalog_preprocessed.assign(Preprocessed_Description=course_catalog['Description'].apply(preprocess))
end = time.time()
print("Preprocess Time:", end - start, "seconds")
course_catalog_preprocessed
# Out:
# Preprocess Time: 17.714894771575928 seconds
#            Code Department                                           Title  \
# 0        AIP 97        AIP                             Academic Internship
# 1       AIP 197        AIP                     Academic Internship Program
# 2     AIP 197DC        AIP                 UCDC: Washington, DC Internship
# 3      AIP 197P        AIP                       Public Service Internship
# 4      AIP 197T        AIP    Academic Internship Program—Special Programs
# ...         ...        ...                                             ...
# 7164   WCWP 100       WCWP                                Academic Writing
# 7165   WCWP 160       WCWP  Technical Writing for Scientists and Engineers
# 7166   WARR 189       WARR      Academic Mentoring and the Writing Process
# 7167   WCWP 198       WCWP                                     Group Study
# 7168   WCWP 500       WCWP                     Apprentice Teaching in WCWP
#
#                    Units                                        Description  \
# 0                   2, 4  Individual placements for field learning. Must...
# 1     2, 4, 6, 8, 10, 12  Individual internship placements integrated wi...
# 2               6, 8, 10  This internship is attached to the University ...
# 3               4, 8, 12  Individual placements for field learning perfo...
# 4                      2  Individual placements for field learning assoc...
# ...                  ...                                                ...
# 7164                   4  An upper-division workshop course in argumenta...
# 7165                   4  An upper-division workshop-style writing cours...
# 7166                   2  Students will gain a fundamental understanding...
# 7167                   2  A directed group study involving research and ...
# 7168              2 or 4  Consideration of pedagogical methods appropria...
#
#                                           Prerequisites           Level  \
# 0     lower-division standing, completion of thirty ...  Lower Division
# 1         upper-division standing; department approval.  Upper Division
# 2         upper-division standing; department approval.  Upper Division
# 3     ninety units completed; 2.5 minimum cumulative...  Upper Division
# 4     ninety units minimum completed; 2.5 minimum cu...  Upper Division
# ...                                                 ...             ...
# 7164  junior/senior standing and must be a Warren Co...  Upper Division
# 7165                            junior/senior standing.  Upper Division
# 7166    permission of instructor is required to enroll.  Upper Division
# 7167                                               none  Upper Division
# 7168                                 graduate standing.        Graduate
#
#                                                     URL  \
# 0     https://cape.ucsd.edu/responses/Results.aspx?N...
# 1     https://cape.ucsd.edu/responses/Results.aspx?N...
# 2     https://cape.ucsd.edu/responses/Results.aspx?N...
# 3     https://cape.ucsd.edu/responses/Results.aspx?N...
# 4     https://cape.ucsd.edu/responses/Results.aspx?N...
# ...                                                 ...
# 7164  https://cape.ucsd.edu/responses/Results.aspx?N...
# 7165  https://cape.ucsd.edu/responses/Results.aspx?N...
# 7166  https://cape.ucsd.edu/responses/Results.aspx?N...
# 7167  https://cape.ucsd.edu/responses/Results.aspx?N...
# 7168  https://cape.ucsd.edu/responses/Results.aspx?N...
#
#                                Preprocessed_Title  \
# 0                             academic internship
# 1                     academic internship program
# 2                   ucdc washington dc internship
# 3                       public service internship
# 4     academic internship program special program
# ...                                           ...
# 7164                             academic writing
# 7165         technical writing scientist engineer
# 7166           academic mentoring writing process
# 7167                                  group study
# 7168                     apprentice teaching wcwp
#
#                                Preprocessed_Description
# 0     individual placement field learning must integ...
# 1     individual internship placement integrated aca...
# 2     internship attached university california wash...
# 3     individual placement field learning performed ...
# 4     individual placement field learning associated...
# ...                                                 ...
# 7164  upper division workshop course argumentation r...
# 7165  upper division workshop style writing course f...
# 7166  student gain fundamental understanding stage w...
# 7167  directed group study involving research analys...
# 7168  consideration pedagogical method appropriate u...
#
# [7169 rows x 10 columns]

# %% [markdown]
# ## Step 2: Retrieve Off-the-Shelf Embeddings

# %%
model = FlagModel('BAAI/bge-small-en-v1.5', 
                  query_instruction_for_retrieval="Represent this sentence for searching relevant passages: ",
                  use_fp16=True) # Setting use_fp16 to True speeds up computation with a slight performance degradation

# %% [markdown]
# ## Step 3: Generate Embeddings for Documents

# %% [markdown]
# ### Step 3a: Title Embeddings

# %%
title_documents = course_catalog_preprocessed['Preprocessed_Title'].values.tolist()

# %%
start = time.time()

# generate embeddings for title
title_document_embeddings = model.encode(title_documents)

end = time.time()
print("Time taken to generate title embeddings:", round(end - start, 2), "seconds")
# Out:
# Inference Embeddings: 100%|████████████████████████████████████████████████████████████| 29/29 [00:52<00:00,  1.82s/it]
# Time taken to generate title embeddings: 52.86 seconds

# %%
# convert title embeddings to dictionary, where key is the index of the course and value is the embeddings
title_embeddings_dict = dict(zip(range(len(title_document_embeddings)), title_document_embeddings.tolist()))

# %%
# export title_embeddings_dict as a json file
title_embeddings_json = json.dumps(title_embeddings_dict)
with open('data/title_bge_embeddings.json', 'w') as f:
    f.write(title_embeddings_json)

# %% [markdown]
# ### Step 3b: Description Embeddings

# %%
desc_documents = course_catalog_preprocessed['Preprocessed_Description'].values.tolist()

# %%
start = time.time()

# generate embeddings for title
desc_document_embeddings = model.encode(desc_documents)

end = time.time()
print("Time taken to generate description embeddings:", round(end - start, 2), "seconds")
# Out:
# Inference Embeddings: 100%|████████████████████████████████████████████████████████████| 29/29 [08:33<00:00, 17.72s/it]
# Time taken to generate description embeddings: 513.93 seconds

# %%
# convert description embeddings to dictionary, where key is the index of the course and value is the embeddings
desc_embeddings_dict = dict(zip(range(len(desc_document_embeddings)), desc_document_embeddings.tolist()))

# %%
# export desc_embeddings_dict as a json file
desc_embeddings_json = json.dumps(desc_embeddings_dict)
with open('data/desc_bge_embeddings.json', 'w') as f:
    f.write(desc_embeddings_json)
