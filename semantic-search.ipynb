# %%
import pandas as pd
import string
import numpy as np
import nltk
import pickle
import torch
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\misaf\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data = pd.read_csv("data\cleaned_course_catalog.csv")
del data[data.columns[0]]
data.head()
# Out:
#         Code Department                                         Title  \
# 0     AIP 97        AIP                           Academic Internship
# 1    AIP 197        AIP                   Academic Internship Program
# 2  AIP 197DC        AIP               UCDC: Washington, DC Internship
# 3   AIP 197P        AIP                     Public Service Internship
# 4   AIP 197T        AIP  Academic Internship Program—Special Programs
#
#                 Units                                        Description  \
# 0                2, 4  Individual placements for field learning. Must...
# 1  2, 4, 6, 8, 10, 12  Individual internship placements integrated wi...
# 2            6, 8, 10  This internship is attached to the University ...
# 3            4, 8, 12  Individual placements for field learning perfo...
# 4                   2  Individual placements for field learning assoc...
#
#                                        Prerequisites
# 0  lower-division standing, completion of thirty ...
# 1      upper-division standing; department approval.
# 2      upper-division standing; department approval.
# 3  ninety units completed; 2.5 minimum cumulative...
# 4  ninety units minimum completed; 2.5 minimum cu...

# %%
#checking null values
data[data.isna().any(axis=1)]
# Out:
#            Code Department                                              Title  \
# 796    CHEM 299       CHEM                              Research in Chemistry
# 1927   BENG 296       BENG                                  Independent Study
# 2760     SE 296         SE                                  Independent Study
# 3799   JAPN 180       JAPN                 Special Topics in Japanese Studies
# 4753  Electives        NaN                                             Varies
# 4774   MATS 296       MATS                                  Independent Study
# 5187    NEU 298        NEU      Neurosciences Independent Study Project (ISP)
# 5474   PHYS 258       PHYS  Astrophysics and Space Physics Special Topics ...
# 5634   POLI 132       POLI             Political Development and Modern China
#
#      Units                                        Description  \
# 796   1–12                                                NaN
# 1927     4                                                NaN
# 2760     4                                                NaN
# 3799     4                                                NaN
# 4753    12  Students enroll in twelve elective units of co...
# 4774     4                                                NaN
# 5187  1–12                                                NaN
# 5474   0–1                                                NaN
# 5634     4                                                NaN
#
#                                           Prerequisites
# 796   graduate-student standing and consent of instr...
# 1927                     consent of instructor. (F,W,S)
# 2760                             consent of instructor.
# 3799                                               none
# 4753                                               none
# 4774                             consent of instructor.
# 5187                     approved ISP proposal. (F,W,S)
# 5474                                               none
# 5634                                               none

# %%
#dropping null values
data = data.dropna().reset_index(drop=True)
data
# Out:
#            Code Department                                           Title  \
# 0        AIP 97        AIP                             Academic Internship
# 1       AIP 197        AIP                     Academic Internship Program
# 2     AIP 197DC        AIP                 UCDC: Washington, DC Internship
# 3      AIP 197P        AIP                       Public Service Internship
# 4      AIP 197T        AIP    Academic Internship Program—Special Programs
# ...         ...        ...                                             ...
# 7156   WCWP 100       WCWP                                Academic Writing
# 7157   WCWP 160       WCWP  Technical Writing for Scientists and Engineers
# 7158   WARR 189       WARR      Academic Mentoring and the Writing Process
# 7159   WCWP 198       WCWP                                     Group Study
# 7160   WCWP 500       WCWP                     Apprentice Teaching in WCWP
#
#                    Units                                        Description  \
# 0                   2, 4  Individual placements for field learning. Must...
# 1     2, 4, 6, 8, 10, 12  Individual internship placements integrated wi...
# 2               6, 8, 10  This internship is attached to the University ...
# 3               4, 8, 12  Individual placements for field learning perfo...
# 4                      2  Individual placements for field learning assoc...
# ...                  ...                                                ...
# 7156                   4  An upper-division workshop course in argumenta...
# 7157                   4  An upper-division workshop-style writing cours...
# 7158                   2  Students will gain a fundamental understanding...
# 7159                   2  A directed group study involving research and ...
# 7160              2 or 4  Consideration of pedagogical methods appropria...
#
#                                           Prerequisites
# 0     lower-division standing, completion of thirty ...
# 1         upper-division standing; department approval.
# 2         upper-division standing; department approval.
# 3     ninety units completed; 2.5 minimum cumulative...
# 4     ninety units minimum completed; 2.5 minimum cu...
# ...                                                 ...
# 7156  junior/senior standing and must be a Warren Co...
# 7157                            junior/senior standing.
# 7158    permission of instructor is required to enroll.
# 7159                                               none
# 7160                                 graduate standing.
#
# [7161 rows x 6 columns]

# %%
# """
# Pre-processing of descriptions include:
# - lowercase
# - remove punctuation
# - tokenization
# - lemmatization
# - (optional) remove stopwords
# """

# %%
def tokenize(text):
    # tokenize
    tokens = text.split(" ")

    # lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]

    return tokens

# %%
# processing description
course_desc = data['Description'].copy()
course_desc

# lowercase
course_desc = course_desc.str.lower()

# remove punctuation
punc_to_remove = '[' + string.punctuation + ']'
course_desc = course_desc.str.replace(punc_to_remove, '', regex=True)

# description_tokens = course_desc.apply(tokenize)

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('sentence-transformers/msmarco-distilbert-base-v4')

# description_embeddings = model.encode(course_desc)
# pickle.dump(description_embeddings, open('description_tokens.pkl', 'wb'))

with open("description_tokens.pkl", "rb") as f:
    description_tokens = pickle.load(f)

# %%
# turn into tensors for faster computations
description_tensors = [torch.tensor(a) for a in description_embeddings];

# will be identifying tensors based on their index in the original tokens list
desc_tensor_dict = dict(zip(range(len(description_tensors)), description_tensors))

# %%
def cos_sim(q_tensor, tensor_dict):
    scores = {}
    for id, tensor in tensor_dict.items():
        magnitude_A = q_tensor.norm()
        magnitude_B = tensor.norm()
        similarity = torch.dot(q_tensor.squeeze(), tensor) / (magnitude_A * magnitude_B)
        # only output scores that are high enough
        if similarity >= 0.2:
            scores[id] = similarity.item()
    return scores

# %%
def parse_query(q):
    encoded = model.encode(q, convert_to_tensor=True)
    return encoded

# %%
def search(q):
    # returns query, language, identifer(optional), url
    parsed = parse_query(q)

    # description score
    docu_scores = cos_sim(parsed, desc_tensor_dict) 
    docu_scores_sorted = {k:v for k,v in sorted(docu_scores.items(), key=lambda item:item[1], reverse=True)}
    
    # # code score
    # code_scores = cos_sim(parsed, code_tokens)
    # code_scores_sorted = {k:v for k,v in sorted(code_scores.items(), key=lambda item:item[1], reverse=True)}
    
    # overall_scores = {**code_scores_sorted, **docu_scores_sorted}
    # sorted_overall_scores = sorted(overall_scores.items(), key=lambda x: x[1], reverse=True)
    
    out = []
    ids = []
    for (id, score) in docu_scores_sorted.items():
        if id not in ids:
            out.append({'query':q, 'course code':data.iloc[id]['Code'], 'course title':data.iloc[id]['Title']})
            # out.append([q, language, train[id]['func_name'], train[id]['func_code_url']])
            ids.append(id)

    print(f"{len(out)} results")   
    return out

# %%
search('lost languages')
# Out:
# 102 results
# [{'query': 'lost languages',
#   'course code': 'LIGN 5',
#   'course title': 'The Linguistics of Invented Languages'},
#  {'query': 'lost languages',
#   'course code': 'COGS 156',
#   'course title': 'Language Development'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 279',
#   'course title': 'Topics in Language Acquisition'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 155',
#   'course title': 'Evolution of Language'},
#  {'query': 'lost languages',
#   'course code': 'PSYC 244',
#   'course title': 'Special Topics in Psycholinguistics'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 255',
#   'course title': 'Topics in Language Evolution'},
#  {'query': 'lost languages',
#   'course code': 'COMM 112G',
#   'course title': 'IM: Language and Globalization'},
#  {'query': 'lost languages',
#   'course code': 'ANSC 116',
#   'course title': 'Languages of the Americas: Mayan'},
#  {'query': 'lost languages',
#   'course code': 'ANSC 194',
#   'course title': 'Language, Migration, Borders'},
#  {'query': 'lost languages',
#   'course code': 'HDS 120',
#   'course title': 'Language Development'},
#  {'query': 'lost languages',
#   'course code': 'JWSP 3',
#   'course title': 'Intermediate Hebrew, Continued'},
#  {'query': 'lost languages',
#   'course code': 'PSYC 234',
#   'course title': 'Evolution of Language'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 171',
#   'course title': 'Child Language Acquisition'},
#  {'query': 'lost languages',
#   'course code': 'JWSP 1',
#   'course title': 'Beginning Hebrew'},
#  {'query': 'lost languages',
#   'course code': 'PHIL 234',
#   'course title': 'Philosophy of Language'},
#  {'query': 'lost languages',
#   'course code': 'JWSP 2',
#   'course title': 'Intermediate Hebrew'},
#  {'query': 'lost languages',
#   'course code': 'EDS 278',
#   'course title': 'Talking Culture, Culture Talking: Voices of Diversity'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 152',
#   'course title': 'Indigenous Languages of the Americas'},
#  {'query': 'lost languages',
#   'course code': 'COGS 154',
#   'course title': 'Communication Disorders in Children and Adults'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 284',
#   'course title': 'Topics in Sign Language Research'},
#  {'query': 'lost languages',
#   'course code': 'COMM 110P',
#   'course title': 'LLC: Language and Human Communication'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 150',
#   'course title': 'Historical Linguistics'},
#  {'query': 'lost languages',
#   'course code': 'ANTH 279',
#   'course title': 'Special Topics in Language and Society'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 282',
#   'course title': 'Biology and Environment in Language Acquisition'},
#  {'query': 'lost languages',
#   'course code': 'LTRU 2A',
#   'course title': 'Second-Year Russian'},
#  {'query': 'lost languages',
#   'course code': 'LTRU 2B',
#   'course title': 'Second-Year Russian'},
#  {'query': 'lost languages',
#   'course code': 'COGS 12',
#   'course title': 'Language, Culture, and Cognition'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 8',
#   'course title': 'Languages and Cultures in America'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 108',
#   'course title': 'Languages of Africa'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 180',
#   'course title': 'Language Representation in the Brain'},
#  {'query': 'lost languages',
#   'course code': 'ECE 252B',
#   'course title': 'Speech Recognition'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 110',
#   'course title': 'Phonetics'},
#  {'query': 'lost languages',
#   'course code': 'PHIL 208',
#   'course title': 'Core Course in Philosophy of Language'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 187',
#   'course title': 'Seminar on Special Topics'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 287',
#   'course title': 'Seminar on Special Topics'},
#  {'query': 'lost languages',
#   'course code': 'COGR 278',
#   'course title': 'Talking Culture, Culture Talking: Voices of Diversity'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 146',
#   'course title': 'Sociolinguistics in Deaf Communities'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 141',
#   'course title': 'Language Structures'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 154',
#   'course title': 'Language and Consciousness'},
#  {'query': 'lost languages',
#   'course code': 'PSYC 169',
#   'course title': 'Brain Damage and Mental Function'},
#  {'query': 'lost languages',
#   'course code': 'TDGR 221A',
#   'course title': 'Speech for the Actor II'},
#  {'query': 'lost languages',
#   'course code': 'TDGR 221B',
#   'course title': 'Speech for the Actor II'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 134P',
#   'course title': 'Advanced Vietnamese for Vietnamese Speakers'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 281',
#   'course title': 'Language Acquisition Theory and Research'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 3',
#   'course title': 'Language as a Social and Cultural Phenomenon'},
#  {'query': 'lost languages',
#   'course code': 'COGR 258',
#   'course title': 'Language in Human Communication'},
#  {'query': 'lost languages',
#   'course code': 'COGS 153',
#   'course title': 'Language Comprehension'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 509',
#   'course title': 'Apprentice Teaching, Head Teaching Assistant'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 271',
#   'course title': 'Advanced Topics in Psycholinguistics'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 134W',
#   'course title': 'Advanced Vietnamese for Vietnamese Speakers'},
#  {'query': 'lost languages',
#   'course code': 'LIDS 19',
#   'course title': 'Directed Study—Language'},
#  {'query': 'lost languages',
#   'course code': 'CSE 256',
#   'course title': 'Statistical Natural Language Processing'},
#  {'query': 'lost languages',
#   'course code': 'LING 256',
#   'course title': 'Statistical Natural Language Processing'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 174',
#   'course title': 'Gender and Language in Society'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 170',
#   'course title': 'Psycholinguistics'},
#  {'query': 'lost languages',
#   'course code': 'ECE 255B',
#   'course title': 'Source Coding'},
#  {'query': 'lost languages',
#   'course code': 'ECON 226',
#   'course title': 'Bayesian and Numerical Methods'},
#  {'query': 'lost languages',
#   'course code': 'LTSP 2D',
#   'course title': 'Intermediate Spanish I: Spanish for Bilingual Speakers'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 134F',
#   'course title': 'Advanced Vietnamese for Vietnamese Speakers'},
#  {'query': 'lost languages',
#   'course code': 'EDS 117GS',
#   'course title': 'Language, Culture, and Education'},
#  {'query': 'lost languages',
#   'course code': 'LTIT 12BR',
#   'course title': 'Italian for Spanish Speakers II'},
#  {'query': 'lost languages',
#   'course code': 'EDS 117',
#   'course title': 'Language, Culture, and Education'},
#  {'query': 'lost languages',
#   'course code': 'EDS 351',
#   'course title': 'Teaching the English Language Learner'},
#  {'query': 'lost languages',
#   'course code': 'LTIT 12AR',
#   'course title': 'Italian for Spanish Speakers I'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 139P',
#   'course title': 'Advanced Hindi for Hindi Speakers'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 177',
#   'course title': 'Multilingualism'},
#  {'query': 'lost languages',
#   'course code': 'LTSP 151',
#   'course title': 'Topics in Chicano/a-Latino/a Cultures'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 139W',
#   'course title': 'Advanced Hindi for Hindi Speakers'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 137P',
#   'course title': 'Advanced Persian for Persian Speakers'},
#  {'query': 'lost languages',
#   'course code': 'ANSC 118',
#   'course title': 'Language and Culture'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 137W',
#   'course title': 'Advanced Persian for Persian Speakers'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 135P',
#   'course title': 'Advanced Korean for Korean Speakers'},
#  {'query': 'lost languages',
#   'course code': 'SOCI 117',
#   'course title': 'Language, Culture, and Education'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 251',
#   'course title': 'Probabilistic Methods in Linguistics'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 135W',
#   'course title': 'Advanced Korean for Korean Speakers'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 139F',
#   'course title': 'Advanced Hindi for Hindi Speakers'},
#  {'query': 'lost languages',
#   'course code': 'LIAB 1D',
#   'course title': 'Arabic Conversation'},
#  {'query': 'lost languages',
#   'course code': 'PSYC 146',
#   'course title': 'Language and Conceptual Development'},
#  {'query': 'lost languages',
#   'course code': 'LIPO 1C',
#   'course title': 'Portuguese Conversation'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 137F',
#   'course title': 'Advanced Persian for Persian Speakers'},
#  {'query': 'lost languages',
#   'course code': 'JAPN 140C',
#   'course title': 'Fourth-Year Japanese'},
#  {'query': 'lost languages',
#   'course code': 'EDS 372',
#   'course title': 'World Language Teaching Practices'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 179',
#   'course title': 'Second Language Acquisition Research'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 240',
#   'course title': 'Field Methods'},
#  {'query': 'lost languages',
#   'course code': 'SOCI 116',
#   'course title': 'Gender and Language in Society'},
#  {'query': 'lost languages',
#   'course code': 'LTSP 100B',
#   'course title': 'Advanced Spanish Reading and Writing for the Humanities and the Social Sciences (heritage speakers)'},
#  {'query': 'lost languages',
#   'course code': 'LTIT 50',
#   'course title': 'Advanced Italian'},
#  {'query': 'lost languages',
#   'course code': 'LIGN 149GS',
#   'course title': 'The Historical Roots of American Sign Language'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 135F',
#   'course title': 'Advanced Korean for Korean Speakers'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 114F',
#   'course title': 'Vietnamese for Vietnamese Speakers'},
#  {'query': 'lost languages',
#   'course code': 'LTCS 180',
#   'course title': 'Programming for the Humanities'},
#  {'query': 'lost languages',
#   'course code': 'LISL 1D',
#   'course title': 'American Sign Language Conversation'},
#  {'query': 'lost languages',
#   'course code': 'SOCI 118E',
#   'course title': 'Sociology of Language'},
#  {'query': 'lost languages',
#   'course code': 'TDGR 212',
#   'course title': 'Acting Practicum'},
#  {'query': 'lost languages',
#   'course code': 'LIPO 1D',
#   'course title': 'Portuguese Conversation'},
#  {'query': 'lost languages',
#   'course code': 'LTEN 259',
#   'course title': 'Transnational Literary Studies'},
#  {'query': 'lost languages',
#   'course code': 'LTSP 137',
#   'course title': 'Caribbean Literature'},
#  {'query': 'lost languages',
#   'course code': 'LIPO 1A',
#   'course title': 'Portuguese Conversation'},
#  {'query': 'lost languages',
#   'course code': 'ETHN 267',
#   'course title': 'History and Memory'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 132P',
#   'course title': 'Advanced Filipino for Filipino Speakers'},
#  {'query': 'lost languages',
#   'course code': 'LIPO 1B',
#   'course title': 'Portuguese Conversation'},
#  {'query': 'lost languages',
#   'course code': 'LIHL 132W',
#   'course title': 'Advanced Filipino for Filipino Speakers'}]
